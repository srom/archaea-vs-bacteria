# %%
import os
from pathlib import Path
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from Bio import Phylo

cwd = os.getcwd()
if cwd.endswith('notebook'):
    os.chdir('..')
    cwd = os.getcwd()

from src.tree.itol_annotation import itol_labels, itol_color_strip_annotations, itol_binary_annotations
from src.tree.tree_util import prune_leaves_with_unknown_id
from src.utils.palette import palette_20

# %%
sns.set_palette('colorblind')
sns.set_style('whitegrid')
sns.set_context('paper', font_scale=1.8)
plt.rcParams['font.family'] = 'Helvetica'

palette = sns.color_palette().as_hex()

data_folder = Path('./data')
assert data_folder.is_dir()

figures_folder = Path('./figures')
assert figures_folder.is_dir()

# %% [markdown]
# # Haloarchaeal PGH tree

# %% [markdown]
# ## Make Halo subtree from wider archaeal GTDB tree

# %%
gtdb_metadata = pd.read_csv(data_folder / 'gtdb_metadata.csv', index_col='ncbi_accession')

halo_genomes = gtdb_metadata[gtdb_metadata['gtdb_phylum'] == 'Halobacteriota'].copy()
halo_genome_accessions = set(halo_genomes.index)

print(f'Number of genomes in Halobacteriota: {len(halo_genomes):,}')
halo_genomes.head()
# Out:
# Number of genomes in Halobacteriota: 739
#                           accession  ambiguous_bases  checkm_completeness  \
# ncbi_accession
# GCA_000224475.1  GB_GCA_000224475.1                0                97.28
# GCA_000306725.1  GB_GCA_000306725.1                0                99.84
# GCA_000336895.1  GB_GCA_000336895.1               58                99.92
# GCA_000337115.1  GB_GCA_000337115.1              127                98.80
# GCA_000415965.1  GB_GCA_000415965.1                0                91.51
#
#                  checkm_contamination  checkm_marker_count  \
# ncbi_accession
# GCA_000224475.1                  1.71                  417
# GCA_000306725.1                  0.00                  228
# GCA_000336895.1                  0.40                  395
# GCA_000337115.1                  0.00                  417
# GCA_000415965.1                  0.38                  417
#
#                        checkm_marker_lineage  checkm_marker_set_count  \
# ncbi_accession
# GCA_000224475.1  f__Halobacteriaceae (UID96)                      263
# GCA_000306725.1     p__Euryarchaeota (UID49)                      153
# GCA_000336895.1  f__Halobacteriaceae (UID85)                      250
# GCA_000337115.1  f__Halobacteriaceae (UID96)                      263
# GCA_000415965.1  f__Halobacteriaceae (UID96)                      263
#
#                  checkm_strain_heterogeneity  coding_bases  coding_density  \
# ncbi_accession
# GCA_000224475.1                          0.0       3138251       86.140952
# GCA_000306725.1                          0.0       2638662       85.872449
# GCA_000336895.1                          0.0       3601508       86.843865
# GCA_000337115.1                          0.0       3319737       85.224715
# GCA_000415965.1                        100.0       2516031       72.393333
#
#                  ...  trna_aa_count  trna_count  trna_selenocysteine_count  \
# ncbi_accession   ...
# GCA_000224475.1  ...             19          46                          0
# GCA_000306725.1  ...             19          53                          0
# GCA_000336895.1  ...             19          66                          0
# GCA_000337115.1  ...             19          48                          0
# GCA_000415965.1  ...             17          44                          0
#
#                   domain     gtdb_phylum       gtdb_class         gtdb_order  \
# ncbi_accession
# GCA_000224475.1  Archaea  Halobacteriota     Halobacteria    Halobacteriales
# GCA_000306725.1  Archaea  Halobacteriota  Methanosarcinia  Methanosarcinales
# GCA_000336895.1  Archaea  Halobacteriota     Halobacteria    Halobacteriales
# GCA_000337115.1  Archaea  Halobacteriota     Halobacteria    Halobacteriales
# GCA_000415965.1  Archaea  Halobacteriota     Halobacteria    Halobacteriales
#
#                         gtdb_family     gtdb_genus                gtdb_species
# ncbi_accession
# GCA_000224475.1      Haloferacaceae     Halolamina      Halolamina sp000224475
# GCA_000306725.1  Methanosarcinaceae   Methanolobus  Methanolobus psychrophilus
# GCA_000336895.1      Haloarculaceae     Haloarcula    Haloarcula argentinensis
# GCA_000337115.1       Natrialbaceae      Natrinema    Natrinema thermotolerans
# GCA_000415965.1      Haloferacaceae  Haloquadratum     Haloquadratum walsbyi_A
#
# [5 rows x 117 columns]

# %%
halo_genomes[halo_genomes['gtdb_genus'] == 'Halogranum']
# Out:
#                           accession  ambiguous_bases  checkm_completeness  \
# ncbi_accession
# GCF_000283335.1  RS_GCF_000283335.1                0                98.61
# GCF_900103715.1  RS_GCF_900103715.1                0                99.57
# GCF_900110465.1  RS_GCF_900110465.1                0                99.38
#
#                  checkm_contamination  checkm_marker_count  \
# ncbi_accession
# GCF_000283335.1                  0.76                  417
# GCF_900103715.1                  0.76                  417
# GCF_900110465.1                  1.77                  417
#
#                        checkm_marker_lineage  checkm_marker_set_count  \
# ncbi_accession
# GCF_000283335.1  f__Halobacteriaceae (UID96)                      263
# GCF_900103715.1  f__Halobacteriaceae (UID96)                      263
# GCF_900110465.1  f__Halobacteriaceae (UID96)                      263
#
#                  checkm_strain_heterogeneity  coding_bases  coding_density  \
# ncbi_accession
# GCF_000283335.1                          0.0       3886827       86.521866
# GCF_900103715.1                          0.0       3302031       87.582685
# GCF_900110465.1                          0.0       4347805       83.842362
#
#                  ...  trna_aa_count  trna_count  trna_selenocysteine_count  \
# ncbi_accession   ...
# GCF_000283335.1  ...             19          67                          0
# GCF_900103715.1  ...             19          53                          0
# GCF_900110465.1  ...             19          59                          0
#
#                   domain     gtdb_phylum    gtdb_class       gtdb_order  \
# ncbi_accession
# GCF_000283335.1  Archaea  Halobacteriota  Halobacteria  Halobacteriales
# GCF_900103715.1  Archaea  Halobacteriota  Halobacteria  Halobacteriales
# GCF_900110465.1  Archaea  Halobacteriota  Halobacteria  Halobacteriales
#
#                     gtdb_family  gtdb_genus                gtdb_species
# ncbi_accession
# GCF_000283335.1  Haloferacaceae  Halogranum           Halogranum rubrum
# GCF_900103715.1  Haloferacaceae  Halogranum  Halogranum gelatinilyticum
# GCF_900110465.1  Haloferacaceae  Halogranum     Halogranum amylolyticum
#
# [3 rows x 117 columns]

# %%
pgh_df = pd.read_csv(data_folder / 'pgh_proteins.csv')

halo_pgh = pgh_df[
    pgh_df['gtdb_phylum'] == 'Halobacteriota'
].reset_index(drop=True).set_index('assembly_accession', drop=True)

halo_pgh_accessions = set(halo_pgh.index)

print(f'Number of PGH proteins in Halobacteriota: {len(halo_pgh):,}')
halo_pgh.head()
# Out:
# Number of PGH proteins in Halobacteriota: 59
#                      domain     gtdb_phylum    gtdb_class       gtdb_order  \
# assembly_accession
# GCF_000710615.1     Archaea  Halobacteriota  Halobacteria  Halobacteriales
# GCF_000710615.1     Archaea  Halobacteriota  Halobacteria  Halobacteriales
# GCF_000710615.1     Archaea  Halobacteriota  Halobacteria  Halobacteriales
# GCF_000710615.1     Archaea  Halobacteriota  Halobacteria  Halobacteriales
# GCF_900156425.1     Archaea  Halobacteriota  Halobacteria  Halobacteriales
#
#                         gtdb_family    gtdb_genus           gtdb_species  \
# assembly_accession
# GCF_000710615.1     Haladaptataceae  Haladaptatus  Haladaptatus cibarius
# GCF_000710615.1     Haladaptataceae  Haladaptatus  Haladaptatus cibarius
# GCF_000710615.1     Haladaptataceae  Haladaptatus  Haladaptatus cibarius
# GCF_000710615.1     Haladaptataceae  Haladaptatus  Haladaptatus cibarius
# GCF_900156425.1     Haladaptataceae  Haladaptatus  Haladaptatus litoreus
#
#                            ncbi_organism_name      protein_id  \
# assembly_accession
# GCF_000710615.1     Haladaptatus cibarius D43  WP_049969648.1
# GCF_000710615.1     Haladaptatus cibarius D43  WP_049969681.1
# GCF_000710615.1     Haladaptatus cibarius D43  WP_049971528.1
# GCF_000710615.1     Haladaptatus cibarius D43  WP_158413663.1
# GCF_900156425.1         Haladaptatus litoreus  WP_076427578.1
#
#                                 pgh_architecture
# assembly_accession
# GCF_000710615.1           PG_binding_1+Amidase_2
# GCF_000710615.1                   SH3_3+NLPC_P60
# GCF_000710615.1       PG_binding_1+Peptidase_M23
# GCF_000710615.1     PG_binding_1+Glucosaminidase
# GCF_900156425.1       PG_binding_1+Peptidase_M23

# %%
archaeal_tree = Phylo.read(data_folder / 'ar53.tree', 'phyloxml')

for leaf in archaeal_tree.get_terminals():
    accession = leaf.name[3:]  # Remove prefix GB_ or RS_
    leaf.name = accession

halo_tree = prune_leaves_with_unknown_id(archaeal_tree, halo_genome_accessions)
halo_tree_accessions = sorted([l.name for l in halo_tree.get_terminals()])

assert len(set(halo_genome_accessions) - set(halo_tree_accessions)) == 0

Phylo.write([halo_tree], data_folder / 'figureS1' / 'halo.tree', 'phyloxml');

# %% [markdown]
# ## Make annotations

# %% [markdown]
# ## Leaf names

# %%
labels = []
for accession in halo_genome_accessions:
    if accession == 'GCF_000283335.1':
        name = 'Halogranum salarium B-1'
    else:
        name = halo_genomes.loc[accession, 'gtdb_species']

    labels.append([accession, name])

itol_labels(labels, data_folder / 'figureS1' / 'halo_labels.txt')

# %% [markdown]
# ## GTDB class colour strip

# %%
classes = halo_genomes['gtdb_class'].unique().tolist()
classes
# Out:
# ['Halobacteria',
#  'Methanosarcinia',
#  'Archaeoglobi',
#  'Methanomicrobia',
#  'Syntropharchaeia',
#  'Methanonatronarchaeia',
#  'Methanosarcinia_A',
#  'Methanocellia',
#  'UBA148',
#  'Bog-38',
#  'Methanoliparia']

# %%
class_data = []
for accession in halo_genome_accessions:
    gtdb_class = halo_genomes.loc[accession, 'gtdb_class']
    class_index = classes.index(gtdb_class)
    colour = palette_20[class_index] 
    class_data.append([accession, colour, gtdb_class])

itol_color_strip_annotations(
    data=class_data,
    output_path=data_folder / 'figureS1' / 'halo_class.txt',
    dataset_label='GTDB class',
    legend_title='GTDB class',
    color_branches=True,
)

# %% [markdown]
# ## Annotate genomes with PGH

# %%
pgh_data = []
for accession in halo_genome_accessions:
    if accession in halo_pgh_accessions:
        label = '1'
    else:
        label = '-1'

    pgh_data.append([accession, label])

itol_binary_annotations(
    data=pgh_data,
    output_path=data_folder / 'figureS1' / 'halo_pgh.txt',
    field_shapes=[1],
    field_labels=['PGH'],
    dataset_label='PGH proteins',
    field_colors=[palette_20[12]],
    legend_title='PGH proteins',
)
